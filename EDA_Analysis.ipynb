# %% [markdown]
# <a href="https://colab.research.google.com/github/karthikv22/EDA-_Analysis-bankruptency/blob/main/EDA_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bank=pd.read_csv(r"/content/drive/MyDrive/ml/Dataset.csv")
pd.set_option('display.max_columns', 200)
pd.set_option('display.width', 200)

# %%
bank.head()
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest   ROA(A) before interest and % after tax   ROA(B) before interest and depreciation after tax   Operating Gross Margin  \
# 0          1                                           0.370594                                        0.424389                                           0.405750                  0.601457
# 1          1                                           0.464291                                        0.538214                                           0.516730                  0.610235
# 2          1                                           0.426071                                        0.499019                                           0.472295                  0.601450
# 3          1                                           0.399844                                        0.451265                                           0.457733                  0.583541
# ...

# %%
bank.shape
# Out:
# (6819, 96)

# %%
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6819 entries, 0 to 6818
# Data columns (total 96 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Bankrupt?                                                 6819 non-null   int64
#  1    ROA(C) before interest and depreciation before interest  6819 non-null   float64
#  2    ROA(A) before interest and % after tax                   6819 non-null   float64
#  3    ROA(B) before interest and depreciation after tax        6819 non-null   float64
#  4    Operating Gross Margin                                   6819 non-null   float64
#  5    Realized Sales Gross Margin                              6819 non-null   float64
#  6    Operating Profit Rate                                    6819 non-null   float64
#  7    Pre-tax net Interest Rate                                6819 non-null   float64
# ...

# %%
bank.columns.tolist()
# Out:
# ['Bankrupt?',
#  ' ROA(C) before interest and depreciation before interest',
#  ' ROA(A) before interest and % after tax',
#  ' ROA(B) before interest and depreciation after tax',
#  ' Operating Gross Margin',
#  ' Realized Sales Gross Margin',
#  ' Operating Profit Rate',
#  ' Pre-tax net Interest Rate',
#  ' After-tax net Interest Rate',
#  ' Non-industry income and expenditure/revenue',
#  ' Continuous interest rate (after tax)',
#  ' Operating Expense Rate',
#  ' Research and development expense rate',
#  ' Cash flow rate',
#  ' Interest-bearing debt interest rate',
#  ' Tax rate (A)',
#  ' Net Value Per Share (B)',
#  ' Net Value Per Share (A)',
#  ' Net Value Per Share (C)',
#  ' Persistent EPS in the Last Four Seasons',
#  ' Cash Flow Per Share',
#  ' Revenue Per Share (Yuan ¥)',
#  ' Operating Profit Per Share (Yuan ¥)',
#  ' Per Share Net profit before tax (Yuan ¥)',
#  ' Realized Sales Gross Profit Growth Rate',
#  ' Operating Profit Growth Rate',
# ...

# %%
#To remove leading spaces in colunms
bank.columns = bank.columns.str.strip()

# %%
bank.isnull().sum()
# Out:
# Bankrupt?                                                  0
# ROA(C) before interest and depreciation before interest    0
# ROA(A) before interest and % after tax                     0
# ROA(B) before interest and depreciation after tax          0
# Operating Gross Margin                                     0
#                                                           ..
# Liability to Equity                                        0
# Degree of Financial Leverage (DFL)                         0
# Interest Coverage Ratio (Interest expense to EBIT)         0
# Net Income Flag                                            0
# Equity to Liability                                        0
# Length: 96, dtype: int64

# %%
bank.duplicated().sum()
# Out:
# np.int64(0)

# %%
#univert anlaysis
bank.describe(include='all').T
# Out:
#                                                      count      mean       std  min       25%       50%       75%  max
# Bankrupt?                                           6819.0  0.032263  0.176710  0.0  0.000000  0.000000  0.000000  1.0
# ROA(C) before interest and depreciation before ...  6819.0  0.505180  0.060686  0.0  0.476527  0.502706  0.535563  1.0
# ROA(A) before interest and % after tax              6819.0  0.558625  0.065620  0.0  0.535543  0.559802  0.589157  1.0
# ROA(B) before interest and depreciation after tax   6819.0  0.553589  0.061595  0.0  0.527277  0.552278  0.584105  1.0
# Operating Gross Margin                              6819.0  0.607948  0.016934  0.0  0.600445  0.605997  0.613914  1.0
# ...                                                    ...       ...       ...  ...       ...       ...       ...  ...
# Liability to Equity                                 6819.0  0.280365  0.014463  0.0  0.276944  0.278778  0.281449  1.0
# ...

# %%
bank.skew().sort_values(ascending=False)
# Out:
# Fixed Assets to Assets                  82.577237
# Current Ratio                           82.577237
# Total income/Total expense              82.332424
# Net Value Growth Rate                   80.291844
# Contingent liabilities/Net worth        79.670620
#                                           ...
# Pre-tax net Interest Rate              -52.482867
# After-tax net Interest Rate            -52.995744
# Continuous interest rate (after tax)   -53.200121
# Operating Profit Rate                  -70.237164
# Operating Profit Growth Rate           -71.688950
# Length: 96, dtype: float64

# %%
bank["Bankrupt?"].value_counts().plot(kind='bar')
plt.xlabel("Bankrupt?")
plt.ylabel("count")
plt.title("Target distribuction")
plt.show()

# %%
missing=pd.DataFrame({
    "missing_count":bank.isnull().sum(),
    "missing_%":bank.isnull().mean()*100
})
missing.head(20)
# Out:
#                                                     missing_count  missing_%
# Bankrupt?                                                       0        0.0
# ROA(C) before interest and depreciation before ...              0        0.0
# ROA(A) before interest and % after tax                          0        0.0
# ROA(B) before interest and depreciation after tax               0        0.0
# Operating Gross Margin                                          0        0.0
# Realized Sales Gross Margin                                     0        0.0
# Operating Profit Rate                                           0        0.0
# Pre-tax net Interest Rate                                       0        0.0
# After-tax net Interest Rate                                     0        0.0
# Non-industry income and expenditure/revenue                     0        0.0
# Continuous interest rate (after tax)                            0        0.0
# ...

# %%
important_val=['Debt ratio %',
                'Current Liability to Assets',
                'Borrowing dependency',
                'Net Income to Total Assets',
                'Gross Profit to Sales']

# %%
for imp in important_val:
  bank[imp].hist(bins=10)
  plt.title(f"ditribution of {imp.strip()}")
  plt.xlabel(imp.strip())
  plt.ylabel("fqr")
  plt.show()

# %%
selected_features=['Debt ratio %',
                'Current Liability to Assets',
                "ROA(A) before interest and % after tax",
                "ROA(B) before interest and depreciation after tax",
                "ROA(C) before interest and depreciation before interest",
                'Borrowing dependency',
                'Net Income to Total Assets',
                'Gross Profit to Sales']

# %%
outlier_summary = []
for col1 in selected_features:
    q1 = bank[col1].quantile(0.25)
    q3 = bank[col1].quantile(0.75)
    iqr = q3 - q1
    lower = q1 - 1.5 * iqr
    upper = q3 + 1.5 * iqr

    outliers = ((bank[col1] < lower) | (bank[col1] > upper)).sum()

    outlier_summary.append({
        "feature": col1,
        "outlier_count": outliers,
        "lower_bound": lower,
        "upper_bound": upper
    })

outlier_df = pd.DataFrame(outlier_summary)
outlier_df["percentage"] = (outlier_df["outlier_count"] / len(bank)) * 100
outlier_df.sort_values("percentage", ascending=False)
# Out:
#                                              feature  outlier_count  lower_bound  upper_bound  percentage
# 2             ROA(A) before interest and % after tax            561     0.455122     0.669579    8.227013
# 6                         Net Income to Total Assets            561     0.752193     0.871012    8.227013
# 3  ROA(B) before interest and depreciation after tax            432     0.442034     0.669348    6.335240
# 4  ROA(C) before interest and depreciation before...            391     0.387973     0.624116    5.733979
# 5                               Borrowing dependency            321     0.361014     0.385425    4.707435
# 7                              Gross Profit to Sales            320     0.580237     0.634119    4.692770
# 1                        Current Liability to Assets             95    -0.046031     0.218856    1.393166
# 0                                       Debt ratio %             30    -0.040980     0.262675    0.439947

# %%
#In bankruptcy data, extreme values (very high debt, very low profit) are often actual distressed firms, not errors.
#If removed → model loses ability to detect high-risk cases

# %%
for col in selected_features:
  bank.boxplot(column=col,by='Bankrupt?')
  plt.title(f"{col} by {'Bankrupt?'}")
  plt.suptitle("")
  plt.xlabel("Bankrupt?")
  plt.ylabel(col)

  plt.show()

# %%
num_df = bank.select_dtypes(include=['int64','float64'])
corr = num_df.corr().abs()
upper = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))
good_corr = (
    upper.stack()
    .reset_index()
    .rename(columns={0: 'correlation'})
    .query("correlation >= 0.85")
    .sort_values(by='correlation', ascending=False)
)

print(good_corr.head(10))
# Out:
#                                   level_0                           level_1  correlation
# 4012        Current Liabilities/Liability    Current Liability to Liability     1.000000
# 4070           Current Liabilities/Equity       Current Liability to Equity     1.000000
# 2812                         Debt ratio %                  Net worth/Assets     1.000000
# 454                Operating Gross Margin             Gross Profit to Sales     1.000000
# 1462              Net Value Per Share (A)           Net Value Per Share (C)     0.999837
# 370                Operating Gross Margin       Realized Sales Gross Margin     0.999518
# 543           Realized Sales Gross Margin             Gross Profit to Sales     0.999518
# 1384              Net Value Per Share (B)           Net Value Per Share (A)     0.999342
# 1385              Net Value Per Share (B)           Net Value Per Share (C)     0.999179
# ...

# %%
target_corr=(
    num_df.corr()['Bankrupt?']
   .abs()
   .sort_values(ascending=False)
   .head(10)
)
print(target_corr)
# Out:
# Bankrupt?                                                  1.000000
# Net Income to Total Assets                                 0.315457
# ROA(A) before interest and % after tax                     0.282941
# ROA(B) before interest and depreciation after tax          0.273051
# ROA(C) before interest and depreciation before interest    0.260807
# Net worth/Assets                                           0.250161
# Debt ratio %                                               0.250161
# Persistent EPS in the Last Four Seasons                    0.219560
# Retained Earnings to Total Assets                          0.217779
# Net profit before tax/Paid-in capital                      0.207857
# Name: Bankrupt?, dtype: float64

# %%
top_features = (
    bank.corr(numeric_only=True)['Bankrupt?']
    .abs()
    .sort_values(ascending=False)
    .head(10)
    .index
)

# correlation matrix of those features
top_corr_matrix = bank[top_features].corr()

plt.figure(figsize=(8,6))
sns.heatmap(top_corr_matrix, annot=True, cmap='coolwarm', center=0)
plt.title("Top Feature Correlation Matrix")
plt.show()

# %%
# Here we took highly co-related columns with target val to tarain and test the data

# %%
train_data=bank[['Bankrupt?','Net Income to Total Assets','ROA(B) before interest and depreciation after tax','ROA(C) before interest and depreciation before interest',
            'Net worth/Assets','Debt ratio %','Persistent EPS in the Last Four Seasons','Retained Earnings to Total Assets','Retained Earnings to Total Assets']]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR,SVC
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
x=train_data.drop("Bankrupt?",axis=1)
y=train_data["Bankrupt?"]

# %%
x.shape
# Out:
# (6819, 8)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((5455, 8), (1364, 8), (5455,), (1364,))

# %%
linear_model=LinearRegression()
linear_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_linear_pred=linear_model.predict(x_test)

# %%
y_linear_pred
# Out:
# array([ 0.03544627,  0.04449802, -0.01869308, ...,  0.07971846,
#         0.09171467, -0.03187137])

# %%
logistic_model=LogisticRegression()
logistic_model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_logistic_pred=logistic_model.predict(x_test)

# %%
y_logistic_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
k_nearest_model=KNeighborsRegressor()
k_nearest_model.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
y_k_nearest_pred=k_nearest_model.predict(x_test)

# %%
y_k_nearest_pred
# Out:
# array([0. , 0. , 0. , ..., 0.2, 0.2, 0. ])

# %%
decision_tree_model=DecisionTreeRegressor()
decision_tree_model.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_decision_tree_pred=decision_tree_model.predict(x_test)

# %%
random_forest_model=RandomForestRegressor()
random_forest_model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_random_forest_pred=random_forest_model.predict(x_test)

# %%
def evaluate_model():
  print("-----------------------linear_model-----------------------------------")
  print("mse:",mean_squared_error(y_test,y_linear_pred))
  print("mae:",mean_absolute_error(y_test,y_linear_pred))
  print("r2_score",r2_score(y_test,y_linear_pred))
  print("-----------------------logistic_model---------------------------------")
  print("mse:",mean_squared_error(y_test,y_logistic_pred))
  print("mae:",mean_absolute_error(y_test,y_logistic_pred))
  print("r2_score",r2_score(y_test,y_logistic_pred))
  print("-----------------------k_nearest_model-------------------------------")
  print("mse:",mean_squared_error(y_test,y_k_nearest_pred))
  print("mae:",mean_absolute_error(y_test,y_k_nearest_pred))
  print("r2_score",r2_score(y_test,y_k_nearest_pred))
  print("-------------------------decision_tree_model-------------------------")
  print("mse:",mean_squared_error(y_test,y_decision_tree_pred))
  print("mae:",mean_absolute_error(y_test,y_decision_tree_pred))
  print("r2_score",r2_score(y_test,y_decision_tree_pred))
  print("-------------------------random_forest_model------------------------")
  print("mse:",mean_squared_error(y_test,y_random_forest_pred))
  print("mae:",mean_absolute_error(y_test,y_random_forest_pred))
  print("r2_score",r2_score(y_test,y_random_forest_pred))

evaluate_model()
# Out:
# -----------------------linear_model-----------------------------------
# mse: 0.030437065240864095
# mae: 0.07403844363824563
# r2_score 0.15433839385381953
# -----------------------logistic_model---------------------------------
# mse: 0.036656891495601175
# mae: 0.036656891495601175
# r2_score -0.01847288801278313
# -----------------------k_nearest_model-------------------------------
# mse: 0.029442815249266865
# mae: 0.04868035190615836
# r2_score 0.1819625763481325
# -------------------------decision_tree_model-------------------------
# mse: 0.04912023460410557
# mae: 0.04912023460410557
# r2_score -0.36475366993712943
# -------------------------random_forest_model------------------------
# mse: 0.028415395894428153
# mae: 0.05247800586510265
# r2_score 0.21050833445335482

# %% [markdown]
# 1. High Financial Leverage Increases Bankruptcy Risk
#
# Companies with higher Debt Ratio % and Borrowing Dependency exhibit significantly higher probability of bankruptcy.
# Business Impact: Excessive reliance on external financing weakens financial stability.
# Action: Flag highly leveraged firms for continuous risk monitoring and limit further credit exposure.
#
# 2. Profitability Acts as a Key Stability Indicator
#
# Firms with low Return on Assets (ROA) and declining Net Income to Total Assets show higher default likelihood.
# Business Impact: Poor profitability reduces the firm’s ability to sustain operations and repay obligations.
# Action: Monitor low-profit firms and initiate early corrective financial measures.
#
# 3. Strong Retained Earnings Reduce Failure Probability
#
# Companies with higher Retained Earnings to Total Assets demonstrate lower bankruptcy rates.
# Business Impact: Internally generated funds improve long-term financial resilience.
# Action: Prefer lending to firms with stable retained earnings and healthy reserves.
#
# 4. Weak Capital Structure Signals Financial Distress
#
# Lower Net Worth to Total Assets ratio is associated with higher bankruptcy occurrence.
# Business Impact: Thin capital base limits the firm’s ability to absorb financial shocks.
# Action: Apply stricter credit and collateral policies for firms with weak net worth.
#
# 5. Combined Financial Weakness Drives Bankruptcy
#
# Bankruptcy risk increases significantly when multiple risk indicators occur together:
#
# High Debt Ratio
#
# High Borrowing Dependency
#
# Low Profitability (ROA)
#
# Low Retained Earnings
#
# Weak Net Worth
#
# Business Insight: Bankruptcy is driven by cumulative financial stress rather than a single factor.
# Action: Implement a composite risk scoring system to classify firms into Low, Medium, and High Risk categories.
#
# 6. Predictive Model Enables Early Risk Detection
#
# The machine learning model identifies leverage, profitability, and earnings strength as primary drivers of bankruptcy.
# Business Impact: The model can serve as an early warning system, enabling proactive intervention before financial failure occurs.
# Action: Integrate the model into credit risk evaluation and portfolio monitoring processes.
#
# 7. Strategic Recommendation
#
# Adopt a data-driven risk monitoring framework that:
#
# Flags high-risk firms early
#
# Reduces exposure to financially unstable companies
#
# Improves credit decision accuracy
#
# Minimizes potential financial losses
